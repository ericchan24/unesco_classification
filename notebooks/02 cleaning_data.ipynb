# %%
import pandas as pd
import numpy as np
from geopy.distance import great_circle

# %% [markdown]
# ### UNESCO Data

# %%
file = '../pickle_files/unesco.p'

# %%
df = pd.read_pickle(file)
df.shape
# Out:
# (241, 16)

# %%
cols_to_keep = ['area_hectares', 'country', 'name']
df = df[cols_to_keep]
df.set_index('name', inplace = True)

# %% [markdown]
# #### Create "UNESCO" column for labels

# %%
df['UNESCO'] = 1

# %% [markdown]
# #### Rename one park

# %%
as_list = df.index.tolist()
idx = as_list.index('Redwood National and State Parks')
as_list[idx] = 'Redwood National Park'
df.index = as_list

# %% [markdown]
# ### US National Park Data

# %%
us_parks = '../pickle_files/us_parks.p'
us_parks_df = pd.read_pickle(us_parks)
us_parks_df.shape
# Out:
# (58, 11)

# %%
us_parks_df['name'] = us_parks_df['name'] + ' National Park'
us_parks_df.set_index('name', inplace = True)

# %%
us_parks_df['area_hectares'] = us_parks_df['sq_km'] * 100
us_parks_df['age'] = 2017 - us_parks_df['est_year']
us_parks_df['country'] = 'United States of America'

# %%
cols_to_keep = ['area_hectares', 'age', 'country']
us_parks_df = us_parks_df[cols_to_keep]

# %% [markdown]
# #### Create a UNESCO column of labels for US Parks

# %%
us_parks = us_parks_df.index.values
unesco_parks = df[df['country'] == 'United States of America'].index.values
mask = np.in1d(us_parks, unesco_parks)
us_parks_df['UNESCO'] = mask 
us_parks_df['UNESCO'] = us_parks_df['UNESCO'].astype(int)

# %% [markdown]
# #### Merge UNESCO with US National parks

# %%
df1 = df.merge(us_parks_df, how='outer', left_index = True, right_index = True)

# %%
cols_to = ['area_hectares_x', 'country_x', 'UNESCO_x',]
cols_from = ['area_hectares_y', 'country_y', 'UNESCO_y']

# %%
def merge_columns(df, cols_to, cols_from):
    '''
    merges common columns in a dataframe
    '''
    for col_to, col_from in zip(cols_to, cols_from):
        mask = df[col_to].isnull()
        df.loc[mask, col_to] = df.loc[mask, col_from]
        df.drop(col_from, axis = 1, inplace = True)
        df.rename(columns = {col_to: col_to[:-2]}, inplace = True)
    return df

# %%
df1 = merge_columns(df1, cols_to, cols_from)

# %% [markdown]
# ### Canadian National Park Data

# %%
canadian_parks = '../pickle_files/canadian_parks.p'
canadian_parks_df = pd.read_pickle(canadian_parks)
canadian_parks_df.shape
# Out:
# (42, 6)

# %%
canadian_parks_df['geographic_location'] = (canadian_parks_df['geographic_location'].str.split(' ')
                                            .apply(lambda x: x[:-2])
                                            .str.join(' '))

# %%
canadian_parks_df.set_index('geographic_location', inplace = True)

# %% [markdown]
# #### Rename One Park

# %%
as_list = canadian_parks_df.index.tolist()
idx = as_list.index('Nahanni National Park Reserve')
as_list[idx] = 'Nahanni National Park'
canadian_parks_df.index = as_list

# %%
canadian_parks_df['park_area_in_square_kilometres'] = canadian_parks_df['park_area_in_square_kilometres'].str.replace(',', '')
canadian_parks_df['area_hectares'] = pd.to_numeric(canadian_parks_df['park_area_in_square_kilometres']) * 100
canadian_parks_df['age'] = 2017 - canadian_parks_df['year_established']

# %% [markdown]
# #### Create a UNESCO column of labels for Canadian Parks

# %%
canadian_parks = canadian_parks_df.index.values
unesco_parks = df[df['country'] == 'Canada'].index.values
mask = np.in1d(canadian_parks, unesco_parks)
canadian_parks_df['UNESCO'] = mask 
canadian_parks_df['UNESCO'] = canadian_parks_df['UNESCO'].astype(int)

# %%
cols_to_keep = ['year_established', 'area_hectares', 'UNESCO', 'age']
canadian_parks_df = canadian_parks_df[cols_to_keep]

# %% [markdown]
# #### Merge UNESCO with Canadian National parks

# %%
df2 = df1.merge(canadian_parks_df, how='outer', left_index = True, right_index = True)

# %%
cols_to = ['area_hectares_x', 'UNESCO_x', 'age_x']
cols_from = ['area_hectares_y', 'UNESCO_y', 'age_y']
df2 = merge_columns(df2, cols_to, cols_from)

# %% [markdown]
# ### TripAdvisor Data

# %%
trip_advisor = '../pickle_files/trip_advisor.p'
tripadvisor_df = pd.read_pickle(trip_advisor)
tripadvisor_df.set_index('name', inplace = True)

# %%
tripadvisor_df.head()
# Out:
#                                       latitude   longitude  critiera7  \
# name
# Aulavik National Park                73.700278 -119.919444        0.0
# Auyuittuq National Park              67.883333  -65.016667        0.0
# Bruce Peninsula National Park        45.238889  -81.614167        0.0
# Cape Breton Highlands National Park  46.716667  -60.659722        0.0
# Elk Island National Park             53.614444 -112.866111        0.0
#
#                                      criteria8  criteria9  criteria10  \
# name
# Aulavik National Park                      0.0        0.0         0.0
# Auyuittuq National Park                    0.0        0.0         0.0
# Bruce Peninsula National Park              0.0        0.0         0.0
# Cape Breton Highlands National Park        0.0        0.0         0.0
# Elk Island National Park                   0.0        0.0         0.0
#
#                                      established  tareviews  \
# name
# Aulavik National Park                       1992          0
# Auyuittuq National Park                     2001         10
# Bruce Peninsula National Park               1987        559
# Cape Breton Highlands National Park         1936       1202
# Elk Island National Park                    1913        434
#
#                                                 ranking rating  visitors  \
# name
# Aulavik National Park                               n/a    n/a         8
# Auyuittuq National Park              (80, 10, 10, 0, 0)    4.5       400
# Bruce Peninsula National Park         (73, 20, 4, 2, 1)    4.5    412623
# Cape Breton Highlands National Park   (84, 12, 2, 1, 1)      5    302827
# Elk Island National Park             (55, 32, 10, 2, 1)    4.5    360678
#
#                                             region
# name
# Aulavik National Park                North America
# Auyuittuq National Park              North America
# Bruce Peninsula National Park        North America
# Cape Breton Highlands National Park  North America
# Elk Island National Park             North America

# %% [markdown]
# ### A few of the Parks in Canada have no Trip Advisor Reviews. Let's look how far they are from the closest parks with reviews.

# %%
tripadvisor_df.loc[tripadvisor_df['ranking'] == 'n/a']
# Out:
#                               latitude   longitude  critiera7  criteria8  \
# name
# Aulavik National Park        73.700278 -119.919444        0.0        0.0
# Qausuittuq National Park     76.000000 -100.000000        0.0        0.0
# Tuktut Nogait National Park  68.818690 -121.749250        0.0        0.0
# Ukkusiksalik National Park   65.341667  -87.305556        0.0        0.0
# Vuntut National Park         68.366667 -139.850000        0.0        0.0
#
#                              criteria9  criteria10  established  tareviews  \
# name
# Aulavik National Park              0.0         0.0         1992          0
# Qausuittuq National Park           0.0         0.0         2015          0
# Tuktut Nogait National Park        0.0         0.0         1998          0
# Ukkusiksalik National Park         0.0         0.0         2003          0
# Vuntut National Park               0.0         0.0         1995          0
#
#                             ranking rating  visitors         region
# name
# Aulavik National Park           n/a    n/a         8  North America
# Qausuittuq National Park        n/a    n/a        21  North America
# Tuktut Nogait National Park     n/a    n/a         2  North America
# Ukkusiksalik National Park      n/a    n/a       300  North America
# Vuntut National Park            n/a    n/a       400  North America

# %%
tripadvisor_df['Age'] = 2017 - tripadvisor_df['established']

# %%
no_ratings = tripadvisor_df.loc[tripadvisor_df['tareviews'] == 0]
ratings = tripadvisor_df.loc[tripadvisor_df['tareviews'] != 0]
no_ratings_lst = no_ratings.index.values
ratings_lst = ratings.index.values

# %%
no_ratings_lat = no_ratings['latitude'].values
no_ratings_lon = no_ratings['longitude'].values

ratings_lat = ratings['latitude'].values
ratings_lon = ratings['longitude'].values

# %%
no_ratings_dict = {}
ratings_dict = {}

# %%
for site, lat, lon in zip(no_ratings_lst, no_ratings_lat, no_ratings_lon):
    no_ratings_dict[site] = [lat, lon]
for site, lat, lon in zip(ratings_lst, ratings_lat, ratings_lon):
    ratings_dict[site] = [lat, lon]

# %%
closest_dict = {}
for site in no_ratings_dict.keys():
    lowest = None
    lowest_site = None
    dists = []

    for site1 in ratings_dict.keys():
        dist = great_circle(no_ratings_dict[site][0:2] , ratings_dict[site1])
        dist = str(dist)
        dist = float(dist[:-3])
        
        if lowest == None or dist < lowest:
            lowest = dist
            lowest_site = site1
    closest_dict[site] = (lowest_site, lowest)

# %%
closest_dict
# Out:
# {'Aulavik National Park': ('Sirmilik National Park', 1216.9442828418512),
#  'Qausuittuq National Park': ('Sirmilik National Park', 648.9066794669081),
#  'Tuktut Nogait National Park': ('Nahanni National Park Reserve',
#   828.0115337095184),
#  'Ukkusiksalik National Park': ('Sirmilik National Park', 883.9479127587751),
#  'Vuntut National Park': ('Nahanni National Park Reserve', 1008.1595892075644)}

# %% [markdown]
# ### The two closest parks to the ones with no ratings are Sirmilik and Nahanni

# %%
tripadvisor_df.loc[['Sirmilik National Park', 'Nahanni National Park Reserve']]
# Out:
#                                 latitude   longitude  critiera7  criteria8  \
# name
# Sirmilik National Park         72.990600  -81.137320        0.0        0.0
# Nahanni National Park Reserve  61.547222 -125.589444        1.0        1.0
#
#                                criteria9  criteria10  established  tareviews  \
# name
# Sirmilik National Park               0.0         0.0         2001          4
# Nahanni National Park Reserve        0.0         0.0         1972         18
#
#                                          ranking rating  visitors  \
# name
# Sirmilik National Park         (50, 50, 0, 0, 0)    4.5        84
# Nahanni National Park Reserve  (89, 11, 0, 0, 0)      5      1082
#
#                                       region  Age
# name
# Sirmilik National Park         North America   16
# Nahanni National Park Reserve  North America   45

# %% [markdown]
# ### These seem similar enough. Let's give the ones with no ratings the same Trip Advisor ratings as the closest part with ratings.

# %%
cols = ['tareviews', 'ranking', 'rating']

for k in closest_dict.keys():
    mask = closest_dict[k][0]
    tripadvisor_df.loc[k, cols] = tripadvisor_df.loc[mask, cols]

# %%
cols_to_keep = ['tareviews', 'ranking', 'rating', 'visitors', 'Age']
tripadvisor_df = tripadvisor_df[cols_to_keep]

# %% [markdown]
# ### Let's merge our Trip Advisor dataframe with our UNESCO dataframe.

# %%
df3 = df2.merge(tripadvisor_df, how = 'outer', left_index = True, right_index = True)

# %%
df3.columns
# Out:
# Index(['area_hectares', 'country', 'UNESCO', 'age', 'year_established',
#        'tareviews', 'ranking', 'rating', 'visitors', 'Age'],
#       dtype='object')

# %% [markdown]
# #### Drop the rows with no tripadvisor reviews

# %%
rows_to_drop = df3.loc[df3['tareviews'].isnull()].index.values
df3.drop(rows_to_drop, axis = 0, inplace = True)
df3.shape
# Out:
# (148, 10)

# %%
df3.columns
# Out:
# Index(['area_hectares', 'country', 'UNESCO', 'age', 'year_established',
#        'tareviews', 'ranking', 'rating', 'visitors', 'Age'],
#       dtype='object')

# %%
df3[df3['area_hectares'].isnull()]
# Out:
#                                                  area_hectares country  \
# El Vizcaíno Biosphere Reserve                              NaN     NaN
# Gulf Islands National Park Reserve                         NaN     NaN
# Nahanni National Park Reserve                              NaN     NaN
# Nanda Devi and Valley of Flowers National Parks            NaN     NaN
# Pinnacles National Park                                    NaN     NaN
# Qausuittuq National Park                                   NaN     NaN
# Simien Mountains National Park                             NaN     NaN
# Thousand Island National Park                              NaN     NaN
# Torngat Mountains National Park                            NaN     NaN
# Uluṟu-Kata Tjuṯa National Park                             NaN     NaN
#
#                                                  UNESCO  age  \
# El Vizcaíno Biosphere Reserve                       NaN  NaN
# Gulf Islands National Park Reserve                  NaN  NaN
# Nahanni National Park Reserve                       NaN  NaN
# Nanda Devi and Valley of Flowers National Parks     NaN  NaN
# Pinnacles National Park                             NaN  NaN
# Qausuittuq National Park                            NaN  NaN
# Simien Mountains National Park                      NaN  NaN
# Thousand Island National Park                       NaN  NaN
# Torngat Mountains National Park                     NaN  NaN
# Uluṟu-Kata Tjuṯa National Park                      NaN  NaN
#
#                                                  year_established  tareviews  \
# El Vizcaíno Biosphere Reserve                                 NaN        1.0
# Gulf Islands National Park Reserve                            NaN       16.0
# Nahanni National Park Reserve                                 NaN       18.0
# Nanda Devi and Valley of Flowers National Parks               NaN      213.0
# Pinnacles National Park                                       NaN      411.0
# Qausuittuq National Park                                      NaN        4.0
# Simien Mountains National Park                                NaN      682.0
# Thousand Island National Park                                 NaN       36.0
# Torngat Mountains National Park                               NaN        1.0
# Uluṟu-Kata Tjuṯa National Park                                NaN     3375.0
#
#                                                            ranking rating  \
# El Vizcaíno Biosphere Reserve                    (100, 0, 0, 0, 0)      5
# Gulf Islands National Park Reserve               (82, 12, 6, 0, 0)      5
# Nahanni National Park Reserve                    (89, 11, 0, 0, 0)      5
# Nanda Devi and Valley of Flowers National Parks  (79, 17, 4, 0, 0)    4.5
# Pinnacles National Park                          (63, 30, 5, 1, 1)    4.5
# Qausuittuq National Park                         (50, 50, 0, 0, 0)    4.5
# Simien Mountains National Park                   (81, 14, 3, 1, 1)    4.5
# Thousand Island National Park                    (52, 30, 8, 5, 5)      4
# Torngat Mountains National Park                  (100, 0, 0, 0, 0)      5
# Uluṟu-Kata Tjuṯa National Park                   (80, 15, 3, 1, 1)    4.5
#
#                                                  visitors    Age
# El Vizcaíno Biosphere Reserve                     13000.0   29.0
# Gulf Islands National Park Reserve               140000.0   14.0
# Nahanni National Park Reserve                      1082.0   45.0
# Nanda Devi and Valley of Flowers National Parks   15000.0   29.0
# Pinnacles National Park                          215555.0    4.0
# Qausuittuq National Park                             21.0    2.0
# Simien Mountains National Park                   250000.0   48.0
# Thousand Island National Park                     90961.0  113.0
# Torngat Mountains National Park                     700.0    9.0
# Uluṟu-Kata Tjuṯa National Park                   279461.0   59.0

# %% [markdown]
# #### Load information for missing rows

# %%
missing_rows = '../pickle_files/missing_rows.p'
missing_rows_df = pd.read_pickle(missing_rows)
missing_rows_df.set_index('site', inplace = True)

# %%
missing_rows_df
# Out:
#                                                  area_hectares  \
# site
# El Vizcaíno Biosphere Reserve                           369631
# Gulf Islands National Park Reserve                        3600
# Nahanni National Park Reserve                          3005000
# Nanda Devi and Valley of Flowers National Parks          71783
# Pinnacles National Park                                  10767
# Qausuittuq National Park                               1100000
# Simien Mountains National Park                           22000
# Torngat Mountains National Park                         970000
# Uluṟu-Kata Tjuṯa National Park                          133372
# Thousand Islands National Park                            2440
# Talampaya National Park                                 215000
# Canadian Rocky Mountain Parks                          2023800
#
#                                                                   country  \
# site
# El Vizcaíno Biosphere Reserve                                      Mexico
# Gulf Islands National Park Reserve                                 Canada
# Nahanni National Park Reserve                                      Canada
# Nanda Devi and Valley of Flowers National Parks                     India
# Pinnacles National Park                          United States of America
# Qausuittuq National Park                                           Canada
# Simien Mountains National Park                                   Ethiopia
# Torngat Mountains National Park                                    Canada
# Uluṟu-Kata Tjuṯa National Park                                  Australia
# Thousand Islands National Park                                     Canada
# Talampaya National Park                                         Argentina
# Canadian Rocky Mountain Parks                                      Canada
#
#                                                  unesco  age
# site
# El Vizcaíno Biosphere Reserve                         1   29
# Gulf Islands National Park Reserve                    0   14
# Nahanni National Park Reserve                         1   45
# Nanda Devi and Valley of Flowers National Parks       1   29
# Pinnacles National Park                               0    4
# Qausuittuq National Park                              0    2
# Simien Mountains National Park                        1   48
# Torngat Mountains National Park                       0    9
# Uluṟu-Kata Tjuṯa National Park                        1   59
# Thousand Islands National Park                        0  113
# Talampaya National Park                               1   20
# Canadian Rocky Mountain Parks                         1  132

# %%
df4 = df3.merge(missing_rows_df, how = 'outer', left_index = True, right_index = True)

# %%
df4
# Out:
#                                                     area_hectares_x  \
# Acadia National Park                                        12300.0
# American Samoa National Park                                 3600.0
# Arches National Park                                        30900.0
# Aulavik National Park                                     1220000.0
# Auyuittuq National Park                                   1970740.0
# Badlands National Park                                      98200.0
# Banc d'Arguin National Park                               1200000.0
# Big Bend National Park                                     324200.0
# Biscayne National Park                                      70000.0
# Black Canyon of the Gunnison National Park                  13300.0
# Bruce Peninsula National Park                               15400.0
# Bryce Canyon National Park                                  14500.0
# Bwindi Impenetrable National Park                           32092.0
# ...                                                                              ...
# Sinharaja Forest Reserve                                                   Sri Lanka
# Sirmilik National Park                                                           NaN
# Sundarbans National Park                                                       India
# Talampaya National Park                                                          NaN
# Te Wahipounamu – South West New Zealand                                  New Zealand
# Teide National Park                                                            Spain
# Terra Nova National Park                                                         NaN
# Theodore Roosevelt National Park                            United States of America
# Thousand Island National Park                                                    NaN
# Thousand Islands National Park                                                   NaN
# Tongariro National Park                                                  New Zealand
# Torngat Mountains National Park                                                  NaN
# Tsingy de Bemaraha Strict Nature Reserve                                  Madagascar
# Tubbataha Reefs Natural Park                                             Philippines
# Tuktut Nogait National Park                                                      NaN
# Ujung Kulon National Park                                                  Indonesia
# Ukkusiksalik National Park                                                       NaN
# Uluṟu-Kata Tjuṯa National Park                                                   NaN
# Vallée de Mai Nature Reserve                                              Seychelles
# Virgin Islands National Park                                United States of America
# Virunga National Park                               Democratic Republic of the Congo
# Voyageurs National Park                                     United States of America
# Vuntut National Park                                                             NaN
# Wapusk National Park                                                             NaN
# Wind Cave National Park                                     United States of America
# Wood Buffalo National Park                                                    Canada
# Yellowstone National Park                                   United States of America
# Yosemite National Park                                      United States of America
# Zion National Park                                          United States of America
# iSimangaliso Wetland Park                                               South Africa
#
#                                                     UNESCO  age_x  \
# Acadia National Park                                   0.0   98.0
# American Samoa National Park                           0.0   29.0
# Arches National Park                                   0.0   46.0
# Aulavik National Park                                  0.0   25.0
# Auyuittuq National Park                                0.0   41.0
# Badlands National Park                                 0.0   39.0
# Banc d'Arguin National Park                            1.0    NaN
# Big Bend National Park                                 0.0   73.0
# Biscayne National Park                                 0.0   37.0
# Black Canyon of the Gunnison National Park             0.0   18.0
# Bruce Peninsula National Park                          0.0   30.0
# Bryce Canyon National Park                             0.0   93.0
# Bwindi Impenetrable National Park                      1.0    NaN
# Canadian Rocky Mountain Parks                          1.0    NaN
# Canyonlands National Park                              0.0   53.0
# Cape Breton Highlands National Park                    0.0   81.0
# Capitol Reef National Park                             0.0   46.0
# Carlsbad Caverns National Park                         1.0   87.0
# Cerrado Protected Areas: Chapada dos Veadeiros ...     1.0    NaN
# Channel Islands National Park                          0.0   37.0
# Chitwan National Park                                  1.0    NaN
# Cocos Island National Park                             1.0    NaN
# Coiba National Park and its Special Zone of Mar...     1.0    NaN
# Congaree National Park                                 0.0   14.0
# Crater Lake National Park                              0.0  115.0
# Cuyahoga Valley National Park                          0.0   17.0
# Darien National Park                                   1.0    NaN
# Death Valley National Park                             0.0   23.0
# Denali National Park                                   0.0  100.0
# Dinosaur Provincial Park                               1.0    NaN
# ...                                                    ...    ...
# Sinharaja Forest Reserve                               1.0    NaN
# Sirmilik National Park                                 0.0   16.0
# Sundarbans National Park                               1.0    NaN
# Talampaya National Park                                NaN    NaN
# Te Wahipounamu – South West New Zealand                1.0    NaN
# Teide National Park                                    1.0    NaN
# Terra Nova National Park                               0.0   60.0
# Theodore Roosevelt National Park                       0.0   39.0
# Thousand Island National Park                          NaN    NaN
# Thousand Islands National Park                         NaN    NaN
# Tongariro National Park                                1.0    NaN
# Torngat Mountains National Park                        NaN    NaN
# Tsingy de Bemaraha Strict Nature Reserve               1.0    NaN
# Tubbataha Reefs Natural Park                           1.0    NaN
# Tuktut Nogait National Park                            0.0   21.0
# Ujung Kulon National Park                              1.0    NaN
# Ukkusiksalik National Park                             0.0   14.0
# Uluṟu-Kata Tjuṯa National Park                         NaN    NaN
# Vallée de Mai Nature Reserve                           1.0    NaN
# Virgin Islands National Park                           0.0   61.0
# Virunga National Park                                  1.0    NaN
# Voyageurs National Park                                0.0   42.0
# Vuntut National Park                                   0.0   22.0
# Wapusk National Park                                   0.0   21.0
# Wind Cave National Park                                0.0  114.0
# Wood Buffalo National Park                             1.0   95.0
# Yellowstone National Park                              1.0  145.0
# Yosemite National Park                                 1.0  127.0
# Zion National Park                                     0.0   98.0
# iSimangaliso Wetland Park                              1.0    NaN
#
#                                                     year_established  \
# Acadia National Park                                             NaN
# American Samoa National Park                                     NaN
# Arches National Park                                             NaN
# Aulavik National Park                                         1992.0
# Auyuittuq National Park                                       1976.0
# Badlands National Park                                           NaN
# Banc d'Arguin National Park                                      NaN
# Big Bend National Park                                           NaN
# Biscayne National Park                                           NaN
# Black Canyon of the Gunnison National Park                       NaN
# Bruce Peninsula National Park                                 1987.0
# Bryce Canyon National Park                                       NaN
# Bwindi Impenetrable National Park                                NaN
# Canadian Rocky Mountain Parks                                    NaN
# Canyonlands National Park                                        NaN
# Cape Breton Highlands National Park                           1936.0
# Capitol Reef National Park                                       NaN
# Carlsbad Caverns National Park                                   NaN
# Cerrado Protected Areas: Chapada dos Veadeiros ...               NaN
# Channel Islands National Park                                    NaN
# Chitwan National Park                                            NaN
# Cocos Island National Park                                       NaN
# Coiba National Park and its Special Zone of Mar...               NaN
# Congaree National Park                                           NaN
# Crater Lake National Park                                        NaN
# Cuyahoga Valley National Park                                    NaN
# Darien National Park                                             NaN
# Death Valley National Park                                       NaN
# Denali National Park                                             NaN
# Dinosaur Provincial Park                                         NaN
# ...                                                              ...
# Sinharaja Forest Reserve                                         NaN
# Sirmilik National Park                                        2001.0
# Sundarbans National Park                                         NaN
# Talampaya National Park                                          NaN
# Te Wahipounamu – South West New Zealand                          NaN
# Teide National Park                                              NaN
# Terra Nova National Park                                      1957.0
# Theodore Roosevelt National Park                                 NaN
# Thousand Island National Park                                    NaN
# Thousand Islands National Park                                   NaN
# Tongariro National Park                                          NaN
# Torngat Mountains National Park                                  NaN
# Tsingy de Bemaraha Strict Nature Reserve                         NaN
# Tubbataha Reefs Natural Park                                     NaN
# Tuktut Nogait National Park                                   1996.0
# Ujung Kulon National Park                                        NaN
# Ukkusiksalik National Park                                    2003.0
# Uluṟu-Kata Tjuṯa National Park                                   NaN
# Vallée de Mai Nature Reserve                                     NaN
# Virgin Islands National Park                                     NaN
# Virunga National Park                                            NaN
# Voyageurs National Park                                          NaN
# Vuntut National Park                                          1995.0
# Wapusk National Park                                          1996.0
# Wind Cave National Park                                          NaN
# Wood Buffalo National Park                                    1922.0
# Yellowstone National Park                                        NaN
# Bryce Canyon National Park                            (90, 7, 1, 1, 1)      5
# Bwindi Impenetrable National Park                    (86, 11, 2, 1, 0)      5
# Canadian Rocky Mountain Parks                        (76, 20, 2, 1, 1)    4.5
# Canyonlands National Park                            (78, 18, 2, 1, 1)    4.5
# Cape Breton Highlands National Park                  (84, 12, 2, 1, 1)      5
# Capitol Reef National Park                           (74, 21, 4, 1, 0)    4.5
# Carlsbad Caverns National Park                       (86, 10, 2, 1, 1)      5
# Cerrado Protected Areas: Chapada dos Veadeiros ...   (80, 16, 2, 1, 1)      5
# Channel Islands National Park                        (74, 22, 3, 1, 0)    4.5
# Chitwan National Park                                (59, 34, 5, 1, 1)    4.5
# Cocos Island National Park                          (74, 11, 11, 3, 1)    4.5
# Coiba National Park and its Special Zone of Mar...   (76, 19, 5, 0, 0)    4.5
# Congaree National Park                               (57, 31, 9, 2, 1)    4.5
# Crater Lake National Park                            (87, 10, 1, 1, 1)      5
# Cuyahoga Valley National Park                       (55, 32, 10, 2, 1)    4.5
# Darien National Park                                 (46, 36, 9, 0, 9)      4
# Death Valley National Park                           (81, 15, 2, 1, 1)      5
# Denali National Park                                 (84, 11, 3, 1, 1)      5
# Dinosaur Provincial Park                             (73, 21, 4, 1, 1)    4.5
# ...                                                                ...    ...
# Sinharaja Forest Reserve                            (57, 26, 11, 4, 2)    4.5
# Sirmilik National Park                               (50, 50, 0, 0, 0)    4.5
# Sundarbans National Park                            (23, 43, 30, 2, 2)      4
# Talampaya National Park                                            NaN    NaN
# Te Wahipounamu – South West New Zealand              (85, 13, 1, 1, 0)      5
# Teide National Park                                  (78, 18, 2, 1, 1)    4.5
# Terra Nova National Park                            (31, 56, 11, 1, 1)      4
# Theodore Roosevelt National Park                     (77, 18, 3, 1, 1)    4.5
# Thousand Island National Park                        (52, 30, 8, 5, 5)      4
# Thousand Islands National Park                                     NaN    NaN
# Tongariro National Park                              (85, 11, 2, 1, 1)      5
# Torngat Mountains National Park                      (100, 0, 0, 0, 0)      5
# Tsingy de Bemaraha Strict Nature Reserve             (81, 13, 4, 1, 1)    4.5
# Tubbataha Reefs Natural Park                         (85, 14, 1, 0, 0)      5
# Tuktut Nogait National Park                          (89, 11, 0, 0, 0)      5
# Ujung Kulon National Park                           (31, 49, 15, 5, 0)      4
# Ukkusiksalik National Park                           (50, 50, 0, 0, 0)    4.5
# Uluṟu-Kata Tjuṯa National Park                       (80, 15, 3, 1, 1)    4.5
# Vallée de Mai Nature Reserve                        (47, 33, 16, 3, 1)      4
# Virgin Islands National Park                         (74, 18, 6, 1, 1)    4.5
# Virunga National Park                                 (93, 6, 1, 0, 0)      5
# Voyageurs National Park                             (49, 39, 12, 0, 0)    4.5
# Vuntut National Park                                 (89, 11, 0, 0, 0)      5
# Wapusk National Park                                 (82, 18, 0, 0, 0)      5
# Wind Cave National Park                              (59, 30, 9, 1, 1)    4.5
# Wood Buffalo National Park                           (73, 27, 0, 0, 0)    4.5
# Yellowstone National Park                            (86, 11, 1, 1, 1)      5
# Arches National Park                                            NaN
# Aulavik National Park                                           NaN
# Auyuittuq National Park                                         NaN
# Badlands National Park                                          NaN
# Banc d'Arguin National Park                                     NaN
# Big Bend National Park                                          NaN
# Biscayne National Park                                          NaN
# Black Canyon of the Gunnison National Park                      NaN
# Bruce Peninsula National Park                                   NaN
# Bryce Canyon National Park                                      NaN
# Bwindi Impenetrable National Park                               NaN
# Canadian Rocky Mountain Parks                             2023800.0
# Canyonlands National Park                                       NaN
# Cape Breton Highlands National Park                             NaN
# Capitol Reef National Park                                      NaN
# Carlsbad Caverns National Park                                  NaN
# Cerrado Protected Areas: Chapada dos Veadeiros ...              NaN
# Channel Islands National Park                                   NaN
# Chitwan National Park                                           NaN
# Cocos Island National Park                                      NaN
# Coiba National Park and its Special Zone of Mar...              NaN
# Congaree National Park                                          NaN
# Crater Lake National Park                                       NaN
# Cuyahoga Valley National Park                                   NaN
# Darien National Park                                            NaN
# Death Valley National Park                                      NaN
# Denali National Park                                            NaN
# Dinosaur Provincial Park                                        NaN
# ...                                                             ...
# Sinharaja Forest Reserve                                        NaN
# Sirmilik National Park                                          NaN
# Sundarbans National Park                                        NaN
# Talampaya National Park                                    215000.0
# Te Wahipounamu – South West New Zealand                         NaN
# Teide National Park                                             NaN
# Terra Nova National Park                                        NaN
# Theodore Roosevelt National Park                                NaN
# Thousand Island National Park                                   NaN
# Thousand Islands National Park                               2440.0
# Tongariro National Park                                         NaN
# Torngat Mountains National Park                            970000.0
# Tsingy de Bemaraha Strict Nature Reserve                        NaN
# Tubbataha Reefs Natural Park                                    NaN
# Tuktut Nogait National Park                                     NaN
# Ujung Kulon National Park                                       NaN
# Ukkusiksalik National Park                                      NaN
# Uluṟu-Kata Tjuṯa National Park                             133372.0
# Vallée de Mai Nature Reserve                                    NaN
# Virgin Islands National Park                                    NaN
# Virunga National Park                                           NaN
# Voyageurs National Park                                         NaN
# Vuntut National Park                                            NaN
# Wapusk National Park                                            NaN
# Wind Cave National Park                                         NaN
# Wood Buffalo National Park                                      NaN
# Yellowstone National Park                                       NaN
# Yosemite National Park                                          NaN
# Zion National Park                                              NaN
# iSimangaliso Wetland Park                                       NaN
#
#                                                     country_y  unesco  age_y
# Acadia National Park                                      NaN     NaN    NaN
# American Samoa National Park                              NaN     NaN    NaN
# Arches National Park                                      NaN     NaN    NaN
# Aulavik National Park                                     NaN     NaN    NaN
# Auyuittuq National Park                                   NaN     NaN    NaN
# Badlands National Park                                    NaN     NaN    NaN
# Banc d'Arguin National Park                               NaN     NaN    NaN
# Big Bend National Park                                    NaN     NaN    NaN
# Biscayne National Park                                    NaN     NaN    NaN
# Black Canyon of the Gunnison National Park                NaN     NaN    NaN
# Bruce Peninsula National Park                             NaN     NaN    NaN
# Bryce Canyon National Park                                NaN     NaN    NaN
# Bwindi Impenetrable National Park                         NaN     NaN    NaN
# Canadian Rocky Mountain Parks                          Canada     1.0  132.0
# Canyonlands National Park                                 NaN     NaN    NaN
# Cape Breton Highlands National Park                       NaN     NaN    NaN
# Capitol Reef National Park                                NaN     NaN    NaN
# Carlsbad Caverns National Park                            NaN     NaN    NaN
# Cerrado Protected Areas: Chapada dos Veadeiros ...        NaN     NaN    NaN
# Channel Islands National Park                             NaN     NaN    NaN
# Chitwan National Park                                     NaN     NaN    NaN
# Cocos Island National Park                                NaN     NaN    NaN
# Coiba National Park and its Special Zone of Mar...        NaN     NaN    NaN
# Congaree National Park                                    NaN     NaN    NaN
# Crater Lake National Park                                 NaN     NaN    NaN
# Cuyahoga Valley National Park                             NaN     NaN    NaN
# Darien National Park                                      NaN     NaN    NaN
# Death Valley National Park                                NaN     NaN    NaN
# Denali National Park                                      NaN     NaN    NaN
# Dinosaur Provincial Park                                  NaN     NaN    NaN
# ...                                                       ...     ...    ...
# Sinharaja Forest Reserve                                  NaN     NaN    NaN
# Sirmilik National Park                                    NaN     NaN    NaN
# Sundarbans National Park                                  NaN     NaN    NaN
# Talampaya National Park                             Argentina     1.0   20.0
# Te Wahipounamu – South West New Zealand                   NaN     NaN    NaN
# Teide National Park                                       NaN     NaN    NaN
# Terra Nova National Park                                  NaN     NaN    NaN
# Theodore Roosevelt National Park                          NaN     NaN    NaN
# Thousand Island National Park                             NaN     NaN    NaN
# Thousand Islands National Park                         Canada     0.0  113.0
# Tongariro National Park                                   NaN     NaN    NaN
# Torngat Mountains National Park                        Canada     0.0    9.0
# Tsingy de Bemaraha Strict Nature Reserve                  NaN     NaN    NaN
# Tubbataha Reefs Natural Park                              NaN     NaN    NaN
# Tuktut Nogait National Park                               NaN     NaN    NaN
# Ujung Kulon National Park                                 NaN     NaN    NaN
# Ukkusiksalik National Park                                NaN     NaN    NaN
# Uluṟu-Kata Tjuṯa National Park                      Australia     1.0   59.0
# Vallée de Mai Nature Reserve                              NaN     NaN    NaN
# Virgin Islands National Park                              NaN     NaN    NaN
# Virunga National Park                                     NaN     NaN    NaN
# Voyageurs National Park                                   NaN     NaN    NaN
# Vuntut National Park                                      NaN     NaN    NaN
# Wapusk National Park                                      NaN     NaN    NaN
# Wind Cave National Park                                   NaN     NaN    NaN
# Wood Buffalo National Park                                NaN     NaN    NaN
# Yellowstone National Park                                 NaN     NaN    NaN
# Yosemite National Park                                    NaN     NaN    NaN
# Zion National Park                                        NaN     NaN    NaN
# iSimangaliso Wetland Park                                 NaN     NaN    NaN
#
# [150 rows x 14 columns]

# %%
cols_to = ['area_hectares_x','Age', 'country_x', 'UNESCO']
cols_from = ['area_hectares_y', 'age_y','country_y', 'unesco']
df4 = merge_columns(df4, cols_to, cols_from)

# %%
cols_to = ['tareviews', 'ranking','rating', 'visitors']
df4.loc['Thousand Islands National Park', cols_to] = df4.loc['Thousand Island National Park', cols_to]
df4.drop('Thousand Island National Park', axis = 0, inplace = True)

# %%
df4.drop(['country', 'year_established', 'age_x'], axis = 1, inplace = True)

# %%
df4 = df4.rename(columns = {'UNES': 'UNESCO', 'A': 'Age'})

# %%
df4.drop('Talampaya National Park', axis = 0, inplace = True)

# %%
df4.to_pickle('../pickle_files/cleaned_df.p')
